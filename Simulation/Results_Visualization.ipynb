# %% [markdown]
# # 1. Compare convergence of uLSIF and SP loss with DCGAN samples
# Fix DR model (MLP5 and ReLU) and Sampler (RS) <br/>
# Plot training losses under lambda's

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
import os
import pandas as pd
# %matplotlib inline

wd = "/home/xin/OneDrive/Working_directory/DDRE_Sampling_GANs/Simulation/Output/Training_loss_fig/Exp4/Compare_Loss_Convergence"
os.chdir(wd)

# name of npy files; under the optimal setting

# file_uLSIF_1 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_0.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
# file_uLSIF_2 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_0.1_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
# file_uLSIF_3 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_1.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
# file_uLSIF_4 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_10.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"

# file_SP_1 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_0.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
# file_SP_2 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_0.1_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
# file_SP_3 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_1.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
# file_SP_4 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_10.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"

# # load training loss
# loss_uLSIF_1 = np.load(file_uLSIF_1)
# loss_uLSIF_2 = np.load(file_uLSIF_2)
# loss_uLSIF_3 = np.load(file_uLSIF_3)
# loss_uLSIF_4 = np.load(file_uLSIF_4)
# loss_SP_1 = np.load(file_SP_1)
# loss_SP_2 = np.load(file_SP_2)
# loss_SP_3 = np.load(file_SP_3)
# loss_SP_4 = np.load(file_SP_4)

# # plot training curves
# filename_uLISF = wd+"/Convergence_uLISF.pdf"
# filename_SP = wd+"/Convergence_SP.pdf"
# num_epochs = 1000
# x = np.arange(start = 1, stop = num_epochs+1)

# f1 = plt.figure()
# #f1.set_size_inches(10, 8)
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')
# plt.plot(x, loss_uLSIF_1, c='r', label = r"$\lambda=0$")
# plt.plot(x, loss_uLSIF_2, c='b', label = r"$\lambda=0.1$")
# plt.plot(x, loss_uLSIF_3, c='y', label = r"$\lambda=1$")
# plt.plot(x, loss_uLSIF_4, c='g', label = r"$\lambda=10$")
# plt.xlabel("epoch")
# plt.ylabel("training loss")
# plt.legend()
# plt.show()
# f1.savefig(filename_uLISF, bbox_inches='tight')

# f2 = plt.figure()
# #f2.set_size_inches(10, 8)
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')
# plt.plot(x, loss_SP_1, c='r', label = r"$\lambda=0$")
# plt.plot(x, loss_SP_2, c='b', label = r"$\lambda=0.1$")
# plt.plot(x, loss_SP_3, c='y', label = r"$\lambda=1$")
# plt.plot(x, loss_SP_4, c='g', label = r"$\lambda=10$")
# plt.xlabel("epoch")
# plt.ylabel("training loss")
# plt.legend()
# plt.show()
# f2.savefig(filename_SP, bbox_inches='tight')


file_uLSIF_1 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_0.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
file_uLSIF_2 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_5.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
file_uLSIF_3 = wd+"/uLSIF/TrainCurve_DRE_uLSIF_LAMBDA_10.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"

file_SP_1 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_0.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
file_SP_2 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_5.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
file_SP_3 = wd+"/SP/TrainCurve_DRE_SP_LAMBDA_10.0_FinalActFn_ReLU_epoch_1000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"

# load training loss
loss_uLSIF_1 = np.load(file_uLSIF_1)
loss_uLSIF_2 = np.load(file_uLSIF_2)
loss_uLSIF_3 = np.load(file_uLSIF_3)
loss_SP_1 = np.load(file_SP_1)
loss_SP_2 = np.load(file_SP_2)
loss_SP_3 = np.load(file_SP_3)

# plot training curves
filename_uLISF = wd+"/Convergence_uLISF.pdf"
filename_SP = wd+"/Convergence_SP.pdf"
num_epochs = 1000
x = np.arange(start = 1, stop = num_epochs+1)

f1 = plt.figure()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.xlim(-50,1120)
# plt.plot(x, loss_uLSIF_1, 'r-', label = r"$\lambda=0$")
plt.plot(x, loss_uLSIF_1, 'r-')
plt.annotate(r"$\lambda=0$", xy=(1005,loss_uLSIF_1[-1]), color=line.get_color(), 
                size=11, va="center", c="r")
plt.plot(x, loss_uLSIF_2, 'b--')
plt.annotate(r"$\lambda=5$", xy=(1005,loss_uLSIF_2[-1]), color=line.get_color(), 
                size=11, va="center", c="b")
plt.plot(x, loss_uLSIF_3, 'g-.')
plt.annotate(r"$\lambda=10$", xy=(1005,loss_uLSIF_3[-1]), color=line.get_color(), 
                size=11, va="center", c="g")

plt.xlabel("epoch")
plt.ylabel("training loss")
# plt.legend()
plt.show()
f1.savefig(filename_uLISF, bbox_inches='tight')

f2 = plt.figure()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.xlim(-50,1120)
plt.plot(x, loss_SP_1, 'r-')
plt.annotate(r"$\lambda=0$", xy=(1005,loss_SP_1[-1]), color=line.get_color(), 
                size=11, va="center", c="r")
plt.plot(x, loss_SP_2, 'b--')
plt.annotate(r"$\lambda=5$", xy=(1005,loss_SP_2[-1]), color=line.get_color(), 
                size=11, va="center", c="b")
plt.plot(x, loss_SP_3, 'g-.')
plt.annotate(r"$\lambda=10$", xy=(1005,loss_SP_3[-1]), color=line.get_color(), 
                size=11, va="center", c="g")
plt.xlabel("epoch")
plt.ylabel("training loss")
# plt.legend()
plt.show()
f2.savefig(filename_SP, bbox_inches='tight')

# %% [markdown]
# # 2. Extra 2

# %% [markdown]
# ## 2.1. % High Quality (epoch_KT) versus Discriminator Errors (RMSE)
# disc-based DRE + SIR, keep training a discriminator but fix the generator.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import os
import seaborn as sns
# %matplotlib inline

wd = "/home/xin/OneDrive/Working_directory/DDRE_Sampling_GANs/Simulation"
os.chdir(wd)

# %%
data_file = wd + "/Extra2_percentHQ_versus_disc_err.csv"
data = np.loadtxt(data_file, delimiter=",")
data_sort_disc = data[data[:,1].argsort()]
data_sort_hqs = data[data[:,2].argsort()]

# %%
# plot percentHQ versus discErr
filename = wd + "/Output/saved_images/percentHQ versus avgdiscErr.pdf"
f1 = plt.figure()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.plot(data_sort_disc[:,1], data_sort_disc[:,2], c='r', ls='-', marker='o')
# plt.plot(epoch, DRS_IS, c='b', ls='-', marker='o', label = "DRS")
# plt.plot(epoch, MHGAN_IS, c='y', ls='-', marker='o', label = "MH-GAN")
# plt.plot(epoch, OURS_IS, c='g', ls='-', marker='o', label = "DRE-F-SP+RS")
plt.xlabel("Avg. Discriminator Error (RMSE)")
plt.ylabel("Avg. \% High Quality Samples")
# plt.legend(fontsize='small')
for i in range(len(data_sort_hqs)):
    if data_sort_hqs[i,0]<=20:
        plt.text(data_sort_hqs[i,1], data_sort_hqs[i,2]+0.2,  '('+str(int(data_sort_hqs[i,0]))+')', fontsize=11)
plt.show()
f1.savefig(filename, bbox_inches='tight')

# %%
# plot percentHQ versus discErr
filename = wd + "/Output/saved_images/avgdiscErr_versus_percentHQ.pdf"
f2 = plt.figure()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.plot(data_sort_hqs[:,2], data_sort_hqs[:,1], c='r', ls='-', marker='o')
plt.xlabel("Avg. \% High Quality Samples")
plt.ylabel("Avg. Discriminator Error (RMSE)")
# plt.legend(fontsize='small')
for i in range(len(data_sort_hqs)):
    if data_sort_hqs[i,0]<=20:
        plt.text(data_sort_hqs[i,2]+0.2, data_sort_hqs[i,1], '('+str(int(data_sort_hqs[i,0]))+')', fontsize=11)
plt.show()
f2.savefig(filename, bbox_inches='tight')

# %%
sns.set_style("white")
filename = wd + "/Output/saved_images/percentHQ versus avgdiscErr.pdf"
ax = sns.regplot(x=data_sort_hqs[:,1], y=data_sort_hqs[:,2],\
                 scatter_kws={"s": 15},\
                 order=3, ci=None, truncate=True)
ax.set(ylabel='\% High Quality Samples', xlabel='Discriminator Error (Avg. RMSE)')
# ax.figure.savefig(filename, bbox_inches='tight')

# %%
sns.set_style("white")
filename = wd + "/Output/saved_images/avgdiscErr_versus_percentHQ.pdf"
ax = sns.regplot(x=data_sort_hqs[:,2], y=data_sort_hqs[:,1],\
                 scatter_kws={"s": 15},\
                 order=2, ci=None, truncate=True)
ax.set(xlabel='\% High Quality Samples', ylabel='Discriminator Error (Avg. RMSE)')
for i in range(len(data_sort_hqs)):
    plt.text(data_sort_hqs[i,2]+0.2, data_sort_hqs[i,1], '('+str(int(data_sort_hqs[i,0]))+')', fontsize=11)
# ax.figure.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ## 2.2.

# %% [markdown]
# # 3. Extra 3

# %% [markdown]
# ## 3.1. Density Ratio Errors versus Epoch_DRE
# DRE-SP/uLSIF+SIR

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import os
import seaborn as sns
# %matplotlib inline

wd = "/home/xin/OneDrive/Working_directory/DDRE_Sampling_GANs/Simulation"
os.chdir(wd)

# %% [markdown]
# ### 3.1.1. lambda=0.0

# %%
data_file_SP = wd + "/Extra3_DR_errors_versus_epochsKT_NoNorm_SP_lambda0.csv"
data_SP = np.loadtxt(data_file_SP, delimiter=",")
epochs = data_SP[:,0]
dr_err_SP0 = data_SP[:,1]
dr_err_hq_SP0 = data_SP[:,2]
dr_err_lq_SP0 = data_SP[:,3]
percentHQ_SP0 = data_SP[:,4]

data_file_uLSIF = wd + "/Extra3_DR_errors_versus_epochsKT_NoNorm_uLSIF_lambda0.csv"
data_uLSIF = np.loadtxt(data_file_uLSIF, delimiter=",")
dr_err_uLSIF0 = data_uLSIF[:,1]
dr_err_hq_uLSIF0 = data_uLSIF[:,2]
dr_err_lq_uLSIF0 = data_uLSIF[:,3]
percentHQ_uLSIF0 = data_uLSIF[:,4]

# %%
## lambda=0: Density ratio errors for all fake samples

filename = wd + "/Output/saved_images/dreErr_versus_epochs_all_fake_samples_lambda0.pdf"

fig, ax1 = plt.subplots()

# color = 'tab:red'
ax1.set_xlabel('Epoch')
# ax1.set_ylabel('Density Ratio Error (RMSE)', color=color)
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_SP0, c='r', ls='-', marker='o', label = "SP (DR Error)")
l2=ax1.plot(epochs, dr_err_uLSIF0, c='b', ls='-', marker='o', label = "uLSIF (DR Error)")
# ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('% High Quality Samples', color=color)  # we already handled the x-label with ax1
ax2.set_ylabel('% High Quality Samples')
l3=ax2.plot(epochs, percentHQ_SP0, c='r', ls='--', marker='+', label = "SP (% HQ)")
l4=ax2.plot(epochs, percentHQ_uLSIF0, c='b', ls='--', marker='+', label = "uLSIF (% HQ)")
# ax2.tick_params(axis='y', labelcolor=color)

lns = l1+l2+l3+l4
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5, fontsize='small')

ax1.set_title("$\lambda=0$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0: Density ratio errors for high quality fake samples
filename = wd + "/Output/saved_images/dreErr_versus_epochs_HQ_fake_samples_lambda0.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_hq_SP0, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_err_hq_uLSIF0, c='b', ls='-', marker='o', label = "uLSIF")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=4)

ax1.set_title("$\lambda=0$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0: Density ratio errors for low quality fake samples
filename = wd + "/Output/saved_images/dreErr_versus_epochs_LQ_fake_samples_lambda0.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_lq_SP0, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_err_lq_uLSIF0, c='b', ls='-', marker='o', label = "uLSIF")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("$\lambda=0$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ### 3.1.2. lambda=0.05

# %%
data_file_SP = wd + "/Extra3_DR_errors_versus_epochsKT_NoNorm_SP_lambda0.05.csv"
data_SP = np.loadtxt(data_file_SP, delimiter=",")
epochs = data_SP[:,0]
dr_err_SP = data_SP[:,1]
dr_err_hq_SP = data_SP[:,2]
dr_err_lq_SP = data_SP[:,3]
percentHQ_SP = data_SP[:,4]

data_file_uLSIF = wd + "/Extra3_DR_errors_versus_epochsKT_NoNorm_uLSIF_lambda0.05.csv"
data_uLSIF = np.loadtxt(data_file_uLSIF, delimiter=",")
dr_err_uLSIF = data_uLSIF[:,1]
dr_err_hq_uLSIF = data_uLSIF[:,2]
dr_err_lq_uLSIF = data_uLSIF[:,3]
percentHQ_uLSIF = data_uLSIF[:,4]

# %%
## lambda=0.05: Density ratio errors for all fake samples

filename = wd + "/Output/saved_images/dreErr_versus_epochs_all_fake_samples_lambda0.05.pdf"

fig, ax1 = plt.subplots()

# color = 'tab:red'
ax1.set_xlabel('Epoch')
# ax1.set_ylabel('Density Ratio Error (RMSE)', color=color)
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_SP, c='r', ls='-', marker='o', label = "SP (DR Error)")
l2=ax1.plot(epochs, dr_err_uLSIF, c='b', ls='-', marker='o', label = "uLSIF (DR Error)")
# ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('% High Quality Samples', color=color)  # we already handled the x-label with ax1
ax2.set_ylabel('% High Quality Samples')
l3=ax2.plot(epochs, percentHQ_SP, c='r', ls='--', marker='+', label = "SP (% HQ)")
l4=ax2.plot(epochs, percentHQ_uLSIF, c='b', ls='--', marker='+', label = "uLSIF (% HQ)")
# ax2.tick_params(axis='y', labelcolor=color)

lns = l1+l2+l3+l4
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=4)

ax1.set_title("$\lambda=0.05$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0.05: Density ratio errors for high quality fake samples
filename = wd + "/Output/saved_images/dreErr_versus_epochs_HQ_fake_samples_lambda0.05.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_hq_SP, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_err_hq_uLSIF, c='b', ls='-', marker='o', label = "uLSIF")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=4)

ax1.set_title("$\lambda=0.05$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0.05: Density ratio errors for low quality fake samples
filename = wd + "/Output/saved_images/dreErr_versus_epochs_LQ_fake_samples_lambda0.05.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_lq_SP, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_err_lq_uLSIF, c='b', ls='-', marker='o', label = "uLSIF")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("$\lambda=0.05$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ### 3.1.3. lambda=0 versus lambda=0.05

# %% [markdown]
# #### SP loss

# %%
### SP loss with diff lambdas: DRE error on all fake
filename = wd + "/Output/saved_images/dreErr_versus_epochs_all_fake_samples_SP_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$ (DR Error)", alpha=0.7)
l2=ax1.plot(epochs, dr_err_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$ (DR Error)", alpha=0.7)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

ax2.set_ylabel('% High Quality Samples')
l3=ax2.plot(epochs, percentHQ_SP0, c='r', ls='--', marker='+', label = "$\lambda=0$ (% HQ)", alpha=0.7)
l4=ax2.plot(epochs, percentHQ_SP, c='b', ls='--', marker='+', label = "$\lambda=0.05$ (% HQ)", alpha=0.7)

lns = l1+l2+l3+l4
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5, fontsize='small')

ax1.set_title("Softplus loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## SP loss with diff lambdas: DRE error on HQ fake
filename = wd + "/Output/saved_images/dreErr_versus_epochs_HQ_fake_samples_SP_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_hq_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_err_hq_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=4)

ax1.set_title("Softplus loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## SP loss with diff lambdas: DRE error on LQ fake
filename = wd + "/Output/saved_images/dreErr_versus_epochs_LQ_fake_samples_SP_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_lq_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_err_lq_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("Softplus loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# #### uLSIF loss

# %%
### SP loss with diff lambdas: DRE error on all fake
filename = wd + "/Output/saved_images/dreErr_versus_epochs_all_fake_samples_uLSIF_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_uLSIF0, c='r', ls='-', marker='o', label = "$\lambda=0$ (DR Error)", alpha=0.7)
l2=ax1.plot(epochs, dr_err_uLSIF, c='b', ls='-', marker='o', label = "$\lambda=0.05$ (DR Error)", alpha=0.7)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

ax2.set_ylabel('% High Quality Samples')
l3=ax2.plot(epochs, percentHQ_uLSIF0, c='r', ls='--', marker='+', label = "$\lambda=0$ (% HQ)", alpha=0.7)
l4=ax2.plot(epochs, percentHQ_uLSIF, c='b', ls='--', marker='+', label = "$\lambda=0.05$ (% HQ)", alpha=0.7)

lns = l1+l2+l3+l4
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=4, fontsize='small')

ax1.set_title("uLSIF loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## uLSIF loss with diff lambdas: DRE error on HQ fake
filename = wd + "/Output/saved_images/dreErr_versus_epochs_HQ_fake_samples_uLSIF_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_hq_uLSIF0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_err_hq_uLSIF, c='b', ls='-', marker='o', label = "$\lambda=0.05$")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=4)

ax1.set_title("uLSIF loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## uLSIF loss with diff lambdas: DRE error on LQ fake
filename = wd + "/Output/saved_images/dreErr_versus_epochs_LQ_fake_samples_uLSIF_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Density Ratio Error (RMSE)')
l1=ax1.plot(epochs, dr_err_lq_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_err_lq_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$")

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("uLSIF loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ## 3.2. Density Ratios (Mean) Comparison
# A side-by-side barchart. Density ratios of all/hq/lq fake samples

# %% [markdown]
# ### 3.2.1. lambda=0

# %%
data_file_SP = wd + "/Extra3_DR_analysis_versus_epochsKT_NoNorm_SP_lambda0.csv"
data_SP = np.loadtxt(data_file_SP, delimiter=",")
epochs = data_SP[:,0]
dr_fake_SP0 = data_SP[:,1]
dr_fake_hq_SP0 = data_SP[:,2]
dr_fake_lq_SP0 = data_SP[:,3]

data_file_uLSIF = wd + "/Extra3_DR_analysis_versus_epochsKT_NoNorm_uLSIF_lambda0.csv"
data_uLSIF = np.loadtxt(data_file_uLSIF, delimiter=",")
dr_fake_uLSIF0 = data_uLSIF[:,1]
dr_fake_hq_uLSIF0 = data_uLSIF[:,2]
dr_fake_lq_uLSIF0 = data_uLSIF[:,3]

ground_truth = np.array([0.919571721583069, 2.21436892876229, 0.000999970376239535])

# %%
## lambda=0: Density ratio for all fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_all_fake_samples_lambda0.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_SP0, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_fake_uLSIF0, c='b', ls='-', marker='o', label = "uLSIF")
ax1.axhline(y=ground_truth[0], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("$\lambda=0$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0: Density ratio for HQ fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_HQ_fake_samples_lambda0.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_hq_SP0, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_fake_hq_uLSIF0, c='b', ls='-', marker='o', label = "uLSIF")
ax1.axhline(y=ground_truth[1], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("$\lambda=0$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0: Density ratio for LQ fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_LQ_fake_samples_lambda0.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_lq_SP0, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_fake_lq_uLSIF0, c='b', ls='-', marker='o', label = "uLSIF")
ax1.axhline(y=ground_truth[2], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("$\lambda=0$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ### 3.2.2. lambda=0.05

# %%
data_file_SP = wd + "/Extra3_DR_analysis_versus_epochsKT_NoNorm_SP_lambda0.05.csv"
data_SP = np.loadtxt(data_file_SP, delimiter=",")
epochs = data_SP[:,0]
dr_fake_SP = data_SP[:,1]
dr_fake_hq_SP = data_SP[:,2]
dr_fake_lq_SP = data_SP[:,3]

data_file_uLSIF = wd + "/Extra3_DR_analysis_versus_epochsKT_NoNorm_uLSIF_lambda0.05.csv"
data_uLSIF = np.loadtxt(data_file_uLSIF, delimiter=",")
dr_fake_uLSIF = data_uLSIF[:,1]
dr_fake_hq_uLSIF = data_uLSIF[:,2]
dr_fake_lq_uLSIF = data_uLSIF[:,3]

ground_truth = np.array([0.919571721583069, 2.21436892876229, 0.000999970376239535])

# %%
## lambda=0.05: Density ratio for all fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_all_fake_samples_lambda0.05.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_SP, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_fake_uLSIF, c='b', ls='-', marker='o', label = "uLSIF")
ax1.axhline(y=ground_truth[0], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("$\lambda=0.05$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0.05: Density ratio for HQ fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_HQ_fake_samples_lambda0.05.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_hq_SP, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_fake_hq_uLSIF, c='b', ls='-', marker='o', label = "uLSIF")
ax1.axhline(y=ground_truth[1], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("$\lambda=0.05$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## lambda=0.05: Density ratio for LQ fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_LQ_fake_samples_lambda0.05.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_lq_SP, c='r', ls='-', marker='o', label = "SP")
l2=ax1.plot(epochs, dr_fake_lq_uLSIF, c='b', ls='-', marker='o', label = "uLSIF")
ax1.axhline(y=ground_truth[2], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("$\lambda=0.05$")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ### 3.2.3. lambda=0 versus lambda=0.05

# %% [markdown]
# #### SP loss

# %%
## SP loss with diff lambds: Density ratio for all fake samples
filename = wd + "/Output/saved_images/dr_versus_epochs_all_fake_samples_SP_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_fake_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$")
ax1.axhline(y=ground_truth[0], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("Softplus loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## SP loss with diff lambds: Density ratio for HQ fake samples
filename = wd + "/Output/saved_images/dr_versus_epochs_HQ_fake_samples_SP_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_hq_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_fake_hq_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$")
ax1.axhline(y=ground_truth[1], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("Softplus loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## SP loss with diff lambds: Density ratio for LQ fake samples

filename = wd + "/Output/saved_images/dr_versus_epochs_LQ_fake_samples_SP_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_lq_SP0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_fake_lq_SP, c='b', ls='-', marker='o', label = "$\lambda=0.05$")
ax1.axhline(y=ground_truth[2], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

ax1.set_title("Softplus loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# #### uLSIF loss

# %%
## uLSIF loss with diff lambds: Density ratio for all fake samples
filename = wd + "/Output/saved_images/dr_versus_epochs_all_fake_samples_uLSIF_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_uLSIF0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_fake_uLSIF, c='b', ls='-', marker='o', label = "$\lambda=0.05$")
ax1.axhline(y=ground_truth[0], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("uLSIF loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
## uLSIF loss with diff lambds: Density ratio for HQ fake samples
filename = wd + "/Output/saved_images/dr_versus_epochs_HQ_fake_samples_uLSIF_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_hq_uLSIF0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_fake_hq_uLSIF, c='b', ls='-', marker='o', label = "$\lambda=0.05$")
ax1.axhline(y=ground_truth[1], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("uLSIF loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
# uLSIF loss with diff lambds: Density ratio for LQ fake samples
filename = wd + "/Output/saved_images/dr_versus_epochs_LQ_fake_samples_uLSIF_diff_lambdas.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg. Density Ratio')
l1=ax1.plot(epochs, dr_fake_lq_uLSIF0, c='r', ls='-', marker='o', label = "$\lambda=0$")
l2=ax1.plot(epochs, dr_fake_lq_uLSIF, c='b', ls='-', marker='o', label = "$\lambda=0.05$")
ax1.axhline(y=ground_truth[2], color='grey')

lns = l1+l2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=5)

ax1.set_title("uLSIF loss")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %% [markdown]
# ## 3.3. Plot training loss

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import os
import seaborn as sns
# %matplotlib inline

wd = "/home/xin/OneDrive/Working_directory/DDRE_Sampling_GANs/Simulation"
os.chdir(wd)

loss_SP_filename = wd+"/Output/Training_loss_fig/extra 3/TrainCurve_DRE_SP_LAMBDA_0.05_FinalActFn_ReLU_epoch_5000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"
loss_uLSIF_filename = wd+"/Output/Training_loss_fig/extra 3/TrainCurve_DRE_uLSIF_LAMBDA_0.05_FinalActFn_ReLU_epoch_5000_PreNetDRE_False_SEED_2019_nSim_0_epochGAN_50_TrainLoss.npy"

loss_SP = np.load(loss_SP_filename)
loss_uLSIF = np.load(loss_uLSIF_filename)

epochs = np.arange(len(loss_SP))

# %%
filename = wd+"/Output/saved_images/training_loss_SP.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Training loss')
l1=ax1.plot(epochs, loss_SP, c='r', ls='-')
ax1.set_title("Softplus loss ($\lambda=0.05$)")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')

# %%
filename = wd+"/Output/saved_images/training_loss_uLSIF.pdf"

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Training loss')
l1=ax1.plot(epochs, loss_uLSIF, c='r', ls='-')
ax1.set_title("uLSIF loss ($\lambda=0.05$)")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig.savefig(filename, bbox_inches='tight')
